# %%
import pandas as pd

# Load headlines
input_path = "processed_headlines_subset.csv"  # adjust as needed
df = pd.read_csv(input_path)

# Convert "Date" to datetime and keep only date part (no time)
df['Date'] = pd.to_datetime(df['Date']).dt.date

# Group by 'Date' and 'Stock_symbol', aggregate headlines into lists
grouped = df.groupby(['Date', 'Stock_symbol'])['Article_title'].apply(list).reset_index()

# Expand list of headlines so each gets its own column: 'headline 1', 'headline 2', ...
headlines_expanded = grouped['Article_title'].apply(pd.Series)
headlines_expanded.columns = [f'headline {i+1}' for i in range(headlines_expanded.shape[1])]

# Concatenate group info with expanded headlines
result = pd.concat([grouped[['Date', 'Stock_symbol']], headlines_expanded], axis=1)

# Save to CSV
result.to_csv("processed_headlines_grouped.csv", index=False)
# Out:
# /tmp/ipykernel_1017663/1492574724.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 14
#      11 grouped = df.groupby(['Date', 'Stock_symbol'])['Article_title'].apply(list).reset_index()
#      13 # Expand list of headlines so each gets its own column: 'headline 1', 'headline 2', ...
# ---> 14 headlines_expanded = grouped['Article_title'].apply(pd.Series)
#      15 headlines_expanded.columns = [f'headline {i+1}' for i in range(headlines_expanded.shape[1])]
#      17 # Concatenate group info with expanded headlines
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/apply.py:1296, in SeriesApply.apply_standard(self)
#    1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
# -> 1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#    1297 else:
#    1298     return obj._constructor(mapped, index=obj.index).__finalize__(
#    1299         obj, method="apply"
#    1300     )
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/frame.py:806, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     804     if columns is not None:
#     805         columns = ensure_index(columns)
# --> 806     arrays, columns, index = nested_data_to_arrays(
#     807         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     808         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     809         data,
#     810         columns,
#     811         index,  # type: ignore[arg-type]
#     812         dtype,
#     813     )
#     814     mgr = arrays_to_mgr(
#     815         arrays,
#     816         columns,
#    (...)
#     819         typ=manager,
#     820     )
#     821 else:
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/internals/construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/internals/construction.py:839, in to_arrays(data, columns, dtype)
#     837     arr, columns = _list_of_dict_to_arrays(data, columns)
#     838 elif isinstance(data[0], ABCSeries):
# --> 839     arr, columns = _list_of_series_to_arrays(data, columns)
#     840 else:
#     841     # last ditch effort
#     842     data = [tuple(x) for x in data]
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/internals/construction.py:869, in _list_of_series_to_arrays(data, columns)
#     866 if columns is None:
#     867     # We know pass_data is non-empty because data[0] is a Series
#     868     pass_data = [x for x in data if isinstance(x, (ABCSeries, ABCDataFrame))]
# --> 869     columns = get_objs_combined_axis(pass_data, sort=False)
#     871 indexer_cache: dict[int, np.ndarray] = {}
#     873 aligned_values = []
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/indexes/api.py:103, in get_objs_combined_axis(objs, intersect, axis, sort, copy)
#      79 """
#      80 Extract combined index: return intersection or union (depending on the
#      81 value of "intersect") of indexes on given axis, or None if all objects
#    (...)
#     100 Index
#     101 """
#     102 obs_idxes = [obj._get_axis(axis) for obj in objs]
# --> 103 return _get_combined_index(obs_idxes, intersect=intersect, sort=sort, copy=copy)
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/indexes/api.py:156, in _get_combined_index(indexes, intersect, sort, copy)
#     154         index = index.intersection(other)
#     155 else:
# --> 156     index = union_indexes(indexes, sort=False)
#     157     index = ensure_index(index)
#     159 if sort:
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/indexes/api.py:305, in union_indexes(indexes, sort)
#     302         result = indexes[0]
#     304     for other in indexes[1:]:
# --> 305         result = result.union(other, sort=None if sort else False)
#     306     return result
#     308 elif kind == "array":
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/indexes/base.py:3336, in Index.union(self, other, sort)
#    3333         return result.sort_values()
#    3334     return result
# -> 3336 result = self._union(other, sort=sort)
#    3338 return self._wrap_setop_result(other, result)
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/indexes/range.py:717, in RangeIndex._union(self, other, sort)
#     715 elif len(self) == 1:
#     716     step_s = step_o
# --> 717 elif len(other) == 1:
#     718     step_o = step_s
#     719 start_r = min(start_s, start_o)
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/pandas/core/indexes/range.py:963, in RangeIndex.__len__(self)
#     959     # Here all "indexes" had 0 length, i.e. were empty.
#     960     # In this case return an empty range index.
#     961     return RangeIndex(0, 0).rename(name)
# --> 963 def __len__(self) -> int:
#     964     """
#     965     return the length of the RangeIndex
#     966     """
#     967     return len(self._range)
#
# KeyboardInterrupt:

# %%
display(result.head(5))
